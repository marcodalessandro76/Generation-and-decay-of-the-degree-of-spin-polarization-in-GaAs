# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from importlib import reload
from mppi import InputFiles as I, Calculators as C, Datasets as D

# %% [markdown]
# # Analysis of the time dependence of the spin polarization

# %% [markdown]
# We analyze the time dependence of the spin polarization. In particular, we are interested in clarifying the behaviour of the polarization when the pulse end.

# %% [markdown]
# We consider the effects of different k sampling, pulse intensity and values of the dephasing.
#
# We choose a field of 100 fs od width and set the computation time to 1000 fs.

# %% [markdown]
# ## k = Gamma - no commutator

# %%
data_dir = 'rt_gamma_no-com/FixSymm/NETime_1000-freq_1.55-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-freq_1.55-pol_circular.spin_magnetization'
mgn_1000 = C.dict_parser(mgn_file)

# %%
data_dir = 'rt_gamma_no-com/FixSymm/NETime_1000-freq_1.55-int_100-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-freq_1.55-int_100-pol_circular.spin_magnetization'
mgn_100 = C.dict_parser(mgn_file)

# %%
data_dir = 'rt_gamma_no-com/FixSymm/NETime_1000-freq_1.55-int_2000-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-freq_1.55-int_2000-pol_circular.spin_magnetization'
mgn_2000 = C.dict_parser(mgn_file)

# %%
data_dir = 'rt_gamma_no-com/FixSymm/NETime_1000-dephase_0.01-freq_1.55-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-dephase_0.01-freq_1.55-pol_circular.spin_magnetization'
mgn_lowdephase = C.dict_parser(mgn_file)

# %%
plt.plot(mgn_1000['T'],mgn_1000['Mc_z'],label='1000')
plt.plot(mgn_100['T'],mgn_100['Mc_z'],label='100')
plt.plot(mgn_2000['T'],mgn_2000['Mc_z'],label='2000')
plt.plot(mgn_lowdephase['T'],mgn_lowdephase['Mc_z'],label='lowdephase')
plt.legend()
plt.ylim(0.49,0.5)
# Out:
# (0.49, 0.5)

# %% [markdown]
# ## k = Gamma and close - no commutator

# %%
data_dir = 'rt_gamma-and-close_no-com/FixSymm/NETime_1000-freq_1.55-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-freq_1.55-pol_circular.spin_magnetization'
mgn_1000 = C.dict_parser(mgn_file)

# %%
data_dir = 'rt_gamma-and-close_no-com/FixSymm/NETime_1000-freq_1.55-int_100-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-freq_1.55-int_100-pol_circular.spin_magnetization'
mgn_100 = C.dict_parser(mgn_file)

# %%
data_dir = 'rt_gamma-and-close_no-com/FixSymm/NETime_1000-freq_1.55-int_2000-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-freq_1.55-int_2000-pol_circular.spin_magnetization'
mgn_2000 = C.dict_parser(mgn_file)

# %%
data_dir = 'rt_gamma-and-close_no-com/FixSymm/NETime_1000-dephase_0.01-freq_1.55-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-dephase_0.01-freq_1.55-pol_circular.spin_magnetization'
mgn_lowdephase = C.dict_parser(mgn_file)

# %%
plt.plot(mgn_1000['T'],mgn_1000['Mc_z'],label='1000')
plt.plot(mgn_100['T'],mgn_100['Mc_z'],label='100')
plt.plot(mgn_2000['T'],mgn_2000['Mc_z'],label='2000')
plt.plot(mgn_lowdephase['T'],mgn_lowdephase['Mc_z'],label='lowdephase')
plt.legend()
plt.ylim(0.49,0.5)
# Out:
# (0.49, 0.5)

# %% [markdown]
# ## k = Random sampling - no commutator

# %%
#data_dir = 'rt_k100random_width100_no-com/FixSymm/NETime_1000-freq_1.55-pol_circular/'
data_dir = 'rt_k100random_no-com/FixSymm/NETime_1000-freq_1.55-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-freq_1.55-pol_circular.spin_magnetization'
car_file = data_dir+'o-NETime_1000-freq_1.55-pol_circular.carriers'
mgn_1000 = C.dict_parser(mgn_file)
car_1000 = C.dict_parser(car_file)

# %%
data_dir = 'rt_k100random_no-com/FixSymm/NETime_1000-freq_1.55-int_100-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-freq_1.55-int_100-pol_circular.spin_magnetization'
mgn_100 = C.dict_parser(mgn_file)

# %%
data_dir = 'rt_k100random_no-com/FixSymm/NETime_1000-freq_1.55-int_2000-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-freq_1.55-int_2000-pol_circular.spin_magnetization'
mgn_2000 = C.dict_parser(mgn_file)

# %%
data_dir = 'rt_k100random_no-com/FixSymm/NETime_1000-dephase_0.01-freq_1.55-pol_circular/'
mgn_file = data_dir+'o-NETime_1000-dephase_0.01-freq_1.55-pol_circular.spin_magnetization'
mgn_lowdephase = C.dict_parser(mgn_file)

# %%
plt.plot(mgn_1000['T'],mgn_1000['Mc_z'],label='1000')
plt.plot(mgn_100['T'],mgn_100['Mc_z'],label='100')
plt.plot(mgn_2000['T'],mgn_2000['Mc_z'],label='2000')
plt.plot(mgn_lowdephase['T'],mgn_lowdephase['Mc_z'],label='lowdephase')
plt.legend()
#plt.ylim(0.36,0.43)

# %%
data_dir = 'rt_k100random_no-com/FixSymm/NETime_1000-freq_1.55-pol_circular-thrs_1e-5/'
mgn_file = data_dir+'o-NETime_1000-freq_1.55-pol_circular-thrs_1e-5.spin_magnetization'
mgn_thrs = C.dict_parser(mgn_file)

# %%
plt.plot(mgn_1000['T'],mgn_1000['Mc_z'],label='low')
plt.plot(mgn_thrs['T'],mgn_thrs['Mc_z'],label='thrs')
plt.legend()

# %%
data_dir = 'rt_k100random_no-com/FixSymm/NETime_1000-freq_1.55-pol_circular-thrs_1e-5/'
car_file = data_dir+'o-NETime_1000-freq_1.55-pol_circular-thrs_1e-5.carriers'
car_thrs = C.dict_parser(car_file)

# %%
car_thrs.keys()
# Out:
# dict_keys(['dN_hole', 'd(N_hole-N_elec)', 'dN_elec', 'time'])

# %%
plt.plot(car_1000['time'],car_1000['dN_elec'])
plt.plot(car_thrs['time'],car_thrs['dN_elec'])

# %%
data_dir = 'rt_k100random_no-com/FixSymm/NETime_10000-dephase_1e-3-freq_1.55-pol_circular/'
mgn_file = data_dir+'o-NETime_10000-dephase_1e-3-freq_1.55-pol_circular.spin_magnetization'
mgn_10pico = C.dict_parser(mgn_file)

# %%
mgn_10pico.keys()
# Out:
# dict_keys(['Ms_z', 'T', 'Mv_z', 'Mv_x', 'Ms_x', 'Ms_y', 'Mc_x', 'Mc_z', 'Mc_y', 'Mv_y'])

# %%
plt.plot(mgn_10pico['T'],mgn_10pico['Mc_z'],label='10pico')

# %%
plt.plot(mgn_10pico['T'],mgn_10pico['Mc_z'],label='10pico')
plt.ylim(-0.01,0.005)
# Out:
# (-0.01, 0.005)
